# %%
import streamlit as st
import pandas as pd
import numpy as np
import pickle
import plotly.express as px

# -----------------------------------
# PAGE CONFIG
# -----------------------------------

st.set_page_config(
    page_title="Smart Water Intelligence Platform",
    layout="wide"
)

# -----------------------------------
# LOAD MODELS
# -----------------------------------

collection_model = pickle.load(
    open("../models/collection_model.pkl", "rb")
)

overflow_model = pickle.load(
    open("../models/overflow_model.pkl", "rb")
)

anomaly_model = pickle.load(
    open("../models/anomaly_model.pkl", "rb")
)

# -----------------------------------
# LOAD DATA
# -----------------------------------

df = pd.read_csv(
    "../data/smart_water_dataset.csv"
)

forecast_df = pd.read_csv(
    "../data/forecast_results.csv"
)

# -----------------------------------
# TITLE
# -----------------------------------

st.title(
    "Smart Sustainable Water Intelligence Platform"
)

st.markdown(
    """
AI-powered platform for:
- Water forecasting
- Overflow prediction
- Leakage detection
- Sustainability analytics
"""
)

# -----------------------------------
# SIDEBAR INPUTS
# -----------------------------------

st.sidebar.header("Input Parameters")

season = st.sidebar.selectbox(
    "Season",
    ["Monsoon", "Summer", "Winter"]
)

season_map = {
    "Monsoon": 0,
    "Summer": 1,
    "Winter": 2
}

season_encoded = season_map[season]

rainfall = st.sidebar.slider(
    "Rainfall (mm)",
    0,
    150,
    50
)

humidity = st.sidebar.slider(
    "Humidity",
    0,
    100,
    70
)

temperature = st.sidebar.slider(
    "Temperature",
    10,
    45,
    28
)

tank_capacity = st.sidebar.selectbox(
    "Tank Capacity",
    [1000, 1500, 2000]
)

water_level = st.sidebar.slider(
    "Current Water Level",
    0,
    tank_capacity,
    500
)

daily_usage = st.sidebar.slider(
    "Daily Usage",
    50,
    700,
    200
)

occupancy = st.sidebar.slider(
    "Occupancy",
    1,
    15,
    5
)

roof_area = st.sidebar.slider(
    "Roof Area",
    50,
    250,
    120
)

efficiency = st.sidebar.slider(
    "Collection Efficiency",
    0.5,
    1.0,
    0.8
)

# -----------------------------------
# CREATE INPUT ARRAY
# -----------------------------------

features = np.array([
    [
        season_encoded,
        rainfall,
        humidity,
        temperature,
        tank_capacity,
        water_level,
        daily_usage,
        occupancy,
        roof_area,
        efficiency
    ]
])

# -----------------------------------
# PREDICTIONS
# -----------------------------------

collection_prediction = (
    collection_model.predict(features)[0]
)

overflow_prediction = (
    overflow_model.predict(features)[0]
)

overflow_probability = (
    overflow_model.predict_proba(features)[0][1]
)

# -----------------------------------
# ANOMALY DETECTION INPUT
# -----------------------------------

anomaly_features = np.array([
    [
        season_encoded,
        rainfall,
        humidity,
        temperature,
        water_level,
        daily_usage,
        occupancy,
        collection_prediction
    ]
])

anomaly_prediction = (
    anomaly_model.predict(anomaly_features)[0]
)

# -----------------------------------
# KPI SECTION
# -----------------------------------

col1, col2, col3, col4 = st.columns(4)

with col1:

    st.metric(
        "Predicted Collection",
        f"{collection_prediction:.2f} L"
    )

with col2:

    st.metric(
        "Overflow Probability",
        f"{overflow_probability * 100:.2f}%"
    )

with col3:

    sustainability_score = max(
        0,
        min(
            100,
            100 - (daily_usage / 5)
            + (collection_prediction / 50)
        )
    )

    st.metric(
        "Sustainability Score",
        f"{sustainability_score:.2f}"
    )

with col4:

    st.metric(
        "Current Tank Level",
        f"{water_level} L"
    )

# -----------------------------------
# ALERTS
# -----------------------------------

st.subheader("System Alerts")

if overflow_prediction == 1:

    st.error(
        "WARNING: High Overflow Risk!"
    )

else:

    st.success(
        "Tank Status: SAFE"
    )

if anomaly_prediction == -1:

    st.warning(
        "Possible Leakage / Abnormal Usage Detected!"
    )

else:

    st.success(
        "No Leakage Detected"
    )

# -----------------------------------
# FORECAST GRAPH
# -----------------------------------

st.subheader(
    "Future Water Collection Forecast"
)

fig = px.line(
    forecast_df,
    x="ds",
    y="yhat",
    title="Forecasted Water Collection"
)

st.plotly_chart(
    fig,
    use_container_width=True
)

# -----------------------------------
# DATA ANALYTICS
# -----------------------------------

st.subheader(
    "Historical Analytics"
)

fig2 = px.scatter(
    df,
    x="water_level",
    y="daily_usage",
    color="overflow_risk",
    title="Water Usage vs Water Level"
)

st.plotly_chart(
    fig2,
    use_container_width=True
)

# -----------------------------------
# SEASONAL ANALYSIS
# -----------------------------------

st.subheader(
    "Seasonal Water Collection"
)

fig3 = px.box(
    df,
    x="season",
    y="water_collected",
    color="season"
)

st.plotly_chart(
    fig3,
    use_container_width=True
)

# -----------------------------------
# RECOMMENDATIONS
# -----------------------------------

st.subheader(
    "AI Recommendations"
)

if rainfall > 80:

    st.info(
        "High rainfall expected. "
        "Increase storage preparation."
    )

if sustainability_score < 50:

    st.warning(
        "Water usage efficiency is low."
    )

if daily_usage > 400:

    st.warning(
        "Daily usage unusually high."
    )

if overflow_probability > 0.8:

    st.error(
        "Immediate overflow mitigation recommended."
    )

# -----------------------------------
# FOOTER
# -----------------------------------

st.markdown("---")

st.caption(
    "Developed using Machine Learning, "
    "Forecasting, Anomaly Detection, "
    "and Sustainability Analytics"
)
# Out:
# 2026-05-10 08:37:13.642 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:15.896 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.357
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-05-10 08:37:17.358 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.360 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.361 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.362 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.364 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.365 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.366 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.367 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.368 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.370 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.371 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.373 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.376 Session state does not function when running a script without `streamlit run`
# 2026-05-10 08:37:17.382 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.384 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.385 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.386 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.388 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.389 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.390 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.392 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.393 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.394 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.395 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.397 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.398 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.399 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.400 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.402 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.403 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.404 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.405 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.406 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.408 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.409 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.410 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.411 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.412 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.414 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.415 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.416 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.417 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.418 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.420 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.421 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.422 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.423 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.424 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.425 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.426 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.428 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.429 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.430 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.431 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.432 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.434 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.436 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.438 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.439 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.440 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.441 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.442 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.443 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.445 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.446 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.447 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.448 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.450 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.451 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.452 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# C:\Users\ASUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# 2026-05-10 08:37:17.492 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.493 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.494 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.495 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.496 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.497 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.498 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.500 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.501 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.502 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.503 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.506 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.507 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.508 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.509 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.510 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.511 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.512 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.513 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.514 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.621 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.622 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.625 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.628 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.629 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.630 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.632 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.903 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-05-10 08:37:17.913 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.915 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.917 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.917 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.919 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.922 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.924 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:17.992 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-05-10 08:37:17.999 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:18.000 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:18.002 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:18.003 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:18.004 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:18.007 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:18.009 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:18.011 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:18.106 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-05-10 08:37:18.139 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:18.141 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:18.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:18.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:18.147 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:18.149 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:18.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:18.151 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:18.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:18.154 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:18.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:18.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:18.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-10 08:37:18.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
